# %%
import sys
print(sys.executable)
# Out:
# C:\Users\chira\OneDrive\Desktop\customer-churn-predictor\my_env\Scripts\python.exe

# %%
import numpy as np
import pandas as pd
import scipy
import matplotlib
import seaborn as sns
import sklearn
import xgboost
import shap
import joblib
import streamlit

print("NumPy:", np.__version__)
print("Pandas:", pd.__version__)
print("SciPy:", scipy.__version__)
print("Scikit-learn:", sklearn.__version__)
print("XGBoost:", xgboost.__version__)
print("SHAP:", shap.__version__)
print("Streamlit:", streamlit.__version__)

print("\n✅ ALL ML PACKAGES IMPORTED SUCCESSFULLY!")
# Out:
# NumPy: 2.5.2
# Pandas: 3.0.5
# SciPy: 1.18.0
# Scikit-learn: 1.9.0
# XGBoost: 3.4.0
# SHAP: 0.52.0
# Streamlit: 1.61.1
#
# ✅ ALL ML PACKAGES IMPORTED SUCCESSFULLY!
